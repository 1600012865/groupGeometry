# %%
import matplotlib.pyplot as plt
import torch
import os

print(os.getcwd())
a = torch.load('/home/xuanjc/geometry/numsagan/loss_curve/sagan_rec1/loss_D.pth')
print(len(a))
plt.plot(range(len(a)),a)
plt.show()
# Out:
# /home/xuanjc/geometry/numsagan/loss_curve/sagan_rec0
# 624
